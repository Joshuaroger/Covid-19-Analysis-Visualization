# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("E:/data1/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136724 entries, 0 to 136723
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    136724 non-null  object
#  1   continent                                   128016 non-null  object
#  2   location                                    136724 non-null  object
#  3   date                                        136724 non-null  object
#  4   total_cases                                 129136 non-null  float64
#  5   new_cases                                   129131 non-null  float64
#  6   new_cases_smoothed                          128091 non-null  float64
#  7   total_deaths                                117875 non-null  float64
#  8   new_deaths                                  118071 non-null  float64
#  9   new_deaths_smoothed                         128091 non-null  float64
#  10  total_cases_per_million                     128474 non-null  float64
#  11  new_cases_per_million                       128469 non-null  float64
#  12  new_cases_smoothed_per_million              127434 non-null  float64
#  13  total_deaths_per_million                    117226 non-null  float64
#  14  new_deaths_per_million                      117422 non-null  float64
#  15  new_deaths_smoothed_per_million             127434 non-null  float64
#  16  reproduction_rate                           107940 non-null  float64
#  17  icu_patients                                16751 non-null   float64
#  18  icu_patients_per_million                    16751 non-null   float64
#  19  hosp_patients                               19159 non-null   float64
#  20  hosp_patients_per_million                   19159 non-null   float64
#  21  weekly_icu_admissions                       1302 non-null    float64
#  22  weekly_icu_admissions_per_million           1302 non-null    float64
#  23  weekly_hosp_admissions                      2100 non-null    float64
#  24  weekly_hosp_admissions_per_million          2100 non-null    float64
#  25  new_tests                                   56518 non-null   float64
#  26  total_tests                                 56846 non-null   float64
#  27  total_tests_per_thousand                    56846 non-null   float64
#  28  new_tests_per_thousand                      56518 non-null   float64
#  29  new_tests_smoothed                          68918 non-null   float64
#  30  new_tests_smoothed_per_thousand             68918 non-null   float64
#  31  positive_rate                               63760 non-null   float64
#  32  tests_per_case                              63099 non-null   float64
#  33  tests_units                                 70971 non-null   object
#  34  total_vaccinations                          35391 non-null   float64
#  35  people_vaccinated                           33809 non-null   float64
#  36  people_fully_vaccinated                     30843 non-null   float64
#  37  total_boosters                              7815 non-null    float64
#  38  new_vaccinations                            29414 non-null   float64
#  39  new_vaccinations_smoothed                   63336 non-null   float64
#  40  total_vaccinations_per_hundred              35391 non-null   float64
#  41  people_vaccinated_per_hundred               33809 non-null   float64
#  42  people_fully_vaccinated_per_hundred         30843 non-null   float64
#  43  total_boosters_per_hundred                  7815 non-null    float64
#  44  new_vaccinations_smoothed_per_million       63336 non-null   float64
#  45  new_people_vaccinated_smoothed              62122 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  62122 non-null   float64
#  47  stringency_index                            111754 non-null  float64
#  48  population                                  135745 non-null  float64
#  49  population_density                          123741 non-null  float64
#  50  median_age                                  117853 non-null  float64
#  51  aged_65_older                               116551 non-null  float64
#  52  aged_70_older                               117210 non-null  float64
#  53  gdp_per_capita                              118635 non-null  float64
#  54  extreme_poverty                             79274 non-null   float64
#  55  cardiovasc_death_rate                       118061 non-null  float64
#  56  diabetes_prevalence                         122002 non-null  float64
#  57  female_smokers                              91962 non-null   float64
#  58  male_smokers                                90634 non-null   float64
#  59  handwashing_facilities                      59423 non-null   float64
#  60  hospital_beds_per_thousand                  107273 non-null  float64
#  61  life_expectancy                             127107 non-null  float64
#  62  human_development_index                     118178 non-null  float64
#  63  excess_mortality_cumulative_absolute        4784 non-null    float64
#  64  excess_mortality_cumulative                 4784 non-null    float64
#  65  excess_mortality                            4784 non-null    float64
#  66  excess_mortality_cumulative_per_million     4784 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 69.9+ MB

# %%
df.shape
# Out:
# (136724, 67)

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# iso_code                                        0
# continent                                    8708
# location                                        0
# date                                            0
# total_cases                                  7588
#                                             ...
# human_development_index                     18546
# excess_mortality_cumulative_absolute       131940
# excess_mortality_cumulative                131940
# excess_mortality                           131940
# excess_mortality_cumulative_per_million    131940
# Length: 67, dtype: int64

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.291360e+05  129131.000000       128091.000000  1.178750e+05
# mean   2.134209e+06    8465.543541         8477.154731  5.219180e+04
# std    1.213694e+07   44053.255495        43479.873000  2.674250e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    2.537750e+03       3.000000           10.429000  8.400000e+01
# 50%    2.922950e+04     105.000000          131.143000  7.820000e+02
# 75%    2.765590e+05    1093.000000         1151.143000  6.777500e+03
# max    2.621817e+08  908289.000000       827220.000000  5.207587e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  118071.000000        128091.000000            128474.000000
# mean      182.995130           168.030421             20795.041960
# std       866.512535           813.761671             34314.237776
# min     -1918.000000          -232.143000                 0.001000
# 25%         0.000000             0.143000               439.045000
# 50%         2.000000             2.000000              3397.465500
# 75%        22.000000            18.857000             26578.401000
# max     18007.000000         14703.286000            250115.038000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          128469.000000                   127434.000000
# mean               89.424485                       89.308125
# std               208.423909                      176.728647
# min             -3125.829000                     -272.971000
# 25%                 0.326000                        1.649000
# 50%                11.356000                       16.080500
# 75%                84.775000                       94.708750
# max              8620.690000                     3385.473000
#
#        total_deaths_per_million  ...  female_smokers  male_smokers  \
# count             117226.000000  ...    91962.000000  90634.000000
# mean                 418.926339  ...       10.589970     32.752186
# std                  681.701178  ...       10.502397     13.515546
# min                    0.000000  ...        0.100000      7.700000
# 25%                   12.743000  ...        1.900000     21.600000
# 50%                   84.834000  ...        6.300000     31.400000
# 75%                  559.690750  ...       19.300000     41.300000
# max                 6029.602000  ...       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            59423.000000               107273.000000    127107.000000
# mean                50.848079                    3.028637        73.262746
# std                 31.818738                    2.454606         7.529988
# min                  1.188000                    0.100000        53.280000
# 25%                 20.859000                    1.300000        67.940000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 83.241000                    4.000000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            118178.000000                           4784.000000
# mean                  0.726110                          32730.488608
# std                   0.150027                          91411.877482
# min                   0.394000                         -31959.400000
# 25%                   0.602000                           -153.050000
# 50%                   0.744000                           2585.550000
# 75%                   0.845000                          21501.875000
# max                   0.957000                         870830.300000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  4784.000000       4784.000000
# mean                      8.844423         16.068150
# std                      16.011001         30.976982
# min                     -27.350000        -95.920000
# 25%                      -0.900000         -0.622500
# 50%                       5.355000          6.755000
# 75%                      13.810000         22.505000
# max                     106.830000        373.740000
#
#        excess_mortality_cumulative_per_million
# count                              4784.000000
# mean                                806.187966
# std                                1185.801394
# min                               -1728.844404
# 25%                                 -39.561719
# 50%                                 376.565768
# 75%                                1386.387282
# max                                6180.171325
#
# [8 rows x 62 columns]

# %%
df.corr()
# Out:
#                                          total_cases  new_cases  \
# total_cases                                 1.000000   0.813417
# new_cases                                   0.813417   1.000000
# new_cases_smoothed                          0.827281   0.986358
# total_deaths                                0.985007   0.820134
# new_deaths                                  0.749813   0.922710
# ...                                              ...        ...
# human_development_index                     0.036329   0.041018
# excess_mortality_cumulative_absolute        0.804879   0.509348
# excess_mortality_cumulative                 0.148420   0.119356
# excess_mortality                            0.049304   0.158892
# excess_mortality_cumulative_per_million     0.245432   0.129158
#
#                                          new_cases_smoothed  total_deaths  \
# total_cases                                        0.827281      0.985007
# new_cases                                          0.986358      0.820134
# new_cases_smoothed                                 1.000000      0.833444
# total_deaths                                       0.833444      1.000000
# new_deaths                                         0.916802      0.783489
# ...                                                     ...           ...
# human_development_index                            0.041329      0.037293
# excess_mortality_cumulative_absolute               0.607748      0.924791
# excess_mortality_cumulative                        0.111655      0.346919
# excess_mortality                                   0.141447      0.133796
# excess_mortality_cumulative_per_million            0.142942      0.395564
#
#                                          new_deaths  new_deaths_smoothed  \
# total_cases                                0.749813             0.772337
# new_cases                                  0.922710             0.915042
# new_cases_smoothed                         0.916802             0.933295
# total_deaths                               0.783489             0.806079
# new_deaths                                 1.000000             0.976878
# ...                                             ...                  ...
# human_development_index                    0.037647             0.039947
# excess_mortality_cumulative_absolute       0.520670             0.657615
# excess_mortality_cumulative                0.299839             0.267616
# excess_mortality                           0.407648             0.341644
# excess_mortality_cumulative_per_million    0.208500             0.221614
#
#                                          total_cases_per_million  \
# total_cases                                             0.116680
# new_cases                                               0.063731
# new_cases_smoothed                                      0.064516
# total_deaths                                            0.104026
# new_deaths                                              0.030875
# ...                                                          ...
# human_development_index                                 0.400314
# excess_mortality_cumulative_absolute                    0.207487
# excess_mortality_cumulative                             0.274356
# excess_mortality                                        0.094521
# excess_mortality_cumulative_per_million                 0.590349
#
#                                          new_cases_per_million  \
# total_cases                                           0.032214
# new_cases                                             0.080369
# new_cases_smoothed                                    0.069051
# total_deaths                                          0.022819
# new_deaths                                            0.048337
# ...                                                        ...
# human_development_index                               0.281577
# excess_mortality_cumulative_absolute                  0.040911
# excess_mortality_cumulative                           0.117652
# excess_mortality                                      0.326300
# excess_mortality_cumulative_per_million               0.180264
#
#                                          new_cases_smoothed_per_million  \
# total_cases                                                    0.038092
# new_cases                                                      0.080566
# new_cases_smoothed                                             0.081561
# total_deaths                                                   0.027321
# new_deaths                                                     0.050532
# ...                                                                 ...
# human_development_index                                        0.326001
# excess_mortality_cumulative_absolute                           0.056120
# excess_mortality_cumulative                                    0.102232
# excess_mortality                                               0.348799
# excess_mortality_cumulative_per_million                        0.202781
#
#                                          total_deaths_per_million  ...  \
# total_cases                                              0.137047  ...
# new_cases                                                0.079529  ...
# new_cases_smoothed                                       0.081298  ...
# total_deaths                                             0.161340  ...
# new_deaths                                               0.077286  ...
# ...                                                           ...  ...
# human_development_index                                  0.351976  ...
# excess_mortality_cumulative_absolute                     0.378131  ...
# excess_mortality_cumulative                              0.655734  ...
# excess_mortality                                         0.245218  ...
# excess_mortality_cumulative_per_million                  0.845715  ...
#
#                                          female_smokers  male_smokers  \
# total_cases                                   -0.004229     -0.008455
# new_cases                                     -0.004893     -0.004861
# new_cases_smoothed                            -0.005233     -0.005023
# total_deaths                                  -0.007113     -0.005725
# new_deaths                                    -0.011531      0.002410
# ...                                                 ...           ...
# human_development_index                        0.573535      0.097331
# excess_mortality_cumulative_absolute          -0.145499     -0.124001
# excess_mortality_cumulative                   -0.298267     -0.152193
# excess_mortality                              -0.180969     -0.006665
# excess_mortality_cumulative_per_million       -0.041409      0.069111
#
#                                          handwashing_facilities  \
# total_cases                                            0.033531
# new_cases                                              0.039339
# new_cases_smoothed                                     0.039766
# total_deaths                                           0.040648
# new_deaths                                             0.047292
# ...                                                         ...
# human_development_index                                0.835939
# excess_mortality_cumulative_absolute                   0.019175
# excess_mortality_cumulative                            0.018222
# excess_mortality                                      -0.010882
# excess_mortality_cumulative_per_million               -0.012081
#
#                                          hospital_beds_per_thousand  \
# total_cases                                               -0.007779
# new_cases                                                 -0.006111
# new_cases_smoothed                                        -0.006450
# total_deaths                                              -0.010062
# new_deaths                                                -0.008433
# ...                                                             ...
# human_development_index                                    0.558220
# excess_mortality_cumulative_absolute                      -0.174818
# excess_mortality_cumulative                               -0.274004
# excess_mortality                                          -0.163262
# excess_mortality_cumulative_per_million                   -0.036615
#
#                                          life_expectancy  \
# total_cases                                     0.021050
# new_cases                                       0.023837
# new_cases_smoothed                              0.023977
# total_deaths                                    0.022744
# new_deaths                                      0.020878
# ...                                                  ...
# human_development_index                         0.913909
# excess_mortality_cumulative_absolute           -0.187306
# excess_mortality_cumulative                    -0.225737
# excess_mortality                               -0.249956
# excess_mortality_cumulative_per_million        -0.252830
#
#                                          human_development_index  \
# total_cases                                             0.036329
# new_cases                                               0.041018
# new_cases_smoothed                                      0.041329
# total_deaths                                            0.037293
# new_deaths                                              0.037647
# ...                                                          ...
# human_development_index                                 1.000000
# excess_mortality_cumulative_absolute                   -0.127296
# excess_mortality_cumulative                            -0.377008
# excess_mortality                                       -0.338066
# excess_mortality_cumulative_per_million                -0.274613
#
#                                          excess_mortality_cumulative_absolute  \
# total_cases                                                          0.804879
# new_cases                                                            0.509348
# new_cases_smoothed                                                   0.607748
# total_deaths                                                         0.924791
# new_deaths                                                           0.520670
# ...                                                                       ...
# human_development_index                                             -0.127296
# excess_mortality_cumulative_absolute                                 1.000000
# excess_mortality_cumulative                                          0.406961
# excess_mortality                                                     0.196812
# excess_mortality_cumulative_per_million                              0.473652
#
#                                          excess_mortality_cumulative  \
# total_cases                                                 0.148420
# new_cases                                                   0.119356
# new_cases_smoothed                                          0.111655
# total_deaths                                                0.346919
# new_deaths                                                  0.299839
# ...                                                              ...
# human_development_index                                    -0.377008
# excess_mortality_cumulative_absolute                        0.406961
# excess_mortality_cumulative                                 1.000000
# excess_mortality                                            0.578198
# excess_mortality_cumulative_per_million                     0.772471
#
#                                          excess_mortality  \
# total_cases                                      0.049304
# new_cases                                        0.158892
# new_cases_smoothed                               0.141447
# total_deaths                                     0.133796
# new_deaths                                       0.407648
# ...                                                   ...
# human_development_index                         -0.338066
# excess_mortality_cumulative_absolute             0.196812
# excess_mortality_cumulative                      0.578198
# excess_mortality                                 1.000000
# excess_mortality_cumulative_per_million          0.385345
#
#                                          excess_mortality_cumulative_per_million
# total_cases                                                             0.245432
# new_cases                                                               0.129158
# new_cases_smoothed                                                      0.142942
# total_deaths                                                            0.395564
# new_deaths                                                              0.208500
# ...                                                                          ...
# human_development_index                                                -0.274613
# excess_mortality_cumulative_absolute                                    0.473652
# excess_mortality_cumulative                                             0.772471
# excess_mortality                                                        0.385345
# excess_mortality_cumulative_per_million                                 1.000000
#
# [62 rows x 62 columns]

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="continent",data=df)
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
#FILTERING ROWS IN DATASET
df_a=df[df["date"]=="2020-11-15"]
df_a=df_a[~df_a["location"].isin(["World","International"])]
print(df_a.head())
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 265        AFG      Asia  Afghanistan  2020-11-15      43035.0       66.0
# 921   OWID_AFR       NaN       Africa  2020-11-15    1976011.0    12568.0
# 1565       ALB    Europe      Albania  2020-11-15      27830.0      597.0
# 2209       DZA    Africa      Algeria  2020-11-15      67679.0      860.0
# 2847       AND    Europe      Andorra  2020-11-15       5872.0      147.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 265              143.143        1605.0        10.0                7.000  ...
# 921            13307.857       47362.0       296.0              286.000  ...
# 1565             517.714         623.0        11.0                9.143  ...
# 2209             804.000        2154.0        15.0               15.143  ...
# 2847              69.857          76.0         1.0                0.143  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 265              NaN           NaN                  37.746
# 921              NaN           NaN                     NaN
# 1565             7.1          51.2                     NaN
# 2209             0.7          30.4                  83.741
# 2847            29.0          37.8                     NaN
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 265                         0.50            64.83                    0.511
# 921                          NaN              NaN                      NaN
# 1565                        2.89            78.57                    0.795
# 2209                        1.90            76.88                    0.748
# 2847                         NaN            83.73                    0.868
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 265                                    NaN                          NaN
# 921                                    NaN                          NaN
# 1565                                   NaN                          NaN
# 2209                                   NaN                          NaN
# 2847                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 265                NaN                                      NaN
# 921                NaN                                      NaN
# 1565               NaN                                      NaN
# 2209               NaN                                      NaN
# 2847               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
max_new_cases=df_a.sort_values("new_cases", ascending=False)
fig=plt.figure(figsize=(15,7))
plt.bar(max_new_cases["location"][:8],max_new_cases["new_cases"][:8],color="#34495E")
plt.xlabel("Countries")
plt.ylabel("New Cases")
plt.title("Top 8 Countries With Maximum New Cases",fontsize=20)
plt.show()

# %%
max_new_deaths=df_a.sort_values("new_deaths",ascending=False)
fig=plt.figure(figsize=(15,7))
plt.bar(max_new_deaths["location"][:8],max_new_deaths["new_deaths"][:8],color="#717D7E")
plt.xlabel("Countries")
plt.ylabel("New Deaths")
plt.title("Top 8 Countries With Maximum New Deaths",fontsize=20)
plt.show()

# %%
print(max_new_cases.tail(10))
print(max_new_deaths.tail(10))
# Out:
#        iso_code      continent                          location        date  \
# 102956      KNA  North America             Saint Kitts and Nevis  2020-11-15
# 104208      VCT  North America  Saint Vincent and the Grenadines  2020-11-15
# 105225      SMR         Europe                        San Marino  2020-11-15
# 108984      SLE         Africa                      Sierra Leone  2020-11-15
# 28130       CRI  North America                        Costa Rica  2020-11-15
# 27328       COG         Africa                             Congo  2020-11-15
# 111583      SLB        Oceania                   Solomon Islands  2020-11-15
# 112207      SOM         Africa                           Somalia  2020-11-15
# 26703       COM         Africa                           Comoros  2020-11-15
# 69175       LSO         Africa                           Lesotho  2020-11-15
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 102956         19.0        0.0               0.000           NaN         NaN
# 104208         78.0        0.0               0.286           NaN         NaN
# 105225       1253.0        0.0              21.714          42.0         0.0
# 108984       2391.0        0.0               1.429          74.0         0.0
# 28130      123223.0        0.0             980.000        1546.0         0.0
# 27328        5515.0        0.0              19.429          92.0         0.0
# 111583         16.0        0.0               0.429           NaN         NaN
# 112207       4301.0        0.0              10.286         107.0         0.0
# 26703         579.0        0.0               2.286           7.0         0.0
# 69175        2041.0        0.0              10.571          44.0         0.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 102956                0.000  ...             NaN           NaN
# 104208                0.000  ...             NaN           NaN
# 105225                0.000  ...             NaN           NaN
# 108984                0.000  ...             8.8          41.3
# 28130                11.714  ...             6.4          17.4
# 27328                 0.000  ...             1.7          52.3
# 111583                0.000  ...             NaN           NaN
# 112207                0.000  ...             NaN           NaN
# 26703                 0.000  ...             4.4          23.6
# 69175                 0.000  ...             0.4          53.9
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 102956                     NaN                        2.30            76.23
# 104208                     NaN                        2.60            72.53
# 105225                     NaN                        3.80            84.97
# 108984                  19.275                         NaN            54.70
# 28130                   83.841                        1.13            80.28
# 27328                   47.964                         NaN            64.57
# 111583                  35.890                        1.40            73.00
# 112207                   9.831                        0.90            57.40
# 26703                   15.574                        2.20            64.32
# 69175                    2.117                         NaN            54.33
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 102956                    0.779                                   NaN
# 104208                    0.738                                   NaN
# 105225                      NaN                                   NaN
# 108984                    0.452                                   NaN
# 28130                     0.810                                   NaN
# 27328                     0.574                                   NaN
# 111583                    0.567                                   NaN
# 112207                      NaN                                   NaN
# 26703                     0.554                                   NaN
# 69175                     0.527                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 102956                          NaN               NaN
# 104208                          NaN               NaN
# 105225                          NaN               NaN
# 108984                          NaN               NaN
# 28130                           NaN               NaN
# 27328                           NaN               NaN
# 111583                          NaN               NaN
# 112207                          NaN               NaN
# 26703                           NaN               NaN
# 69175                           NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 102956                                      NaN
# 104208                                      NaN
# 105225                                      NaN
# 108984                                      NaN
# 28130                                       NaN
# 27328                                       NaN
# 111583                                      NaN
# 112207                                      NaN
# 26703                                       NaN
# 69175                                       NaN
#
# [10 rows x 67 columns]
#        iso_code      continent                          location        date  \
# 67314       LAO           Asia                              Laos  2020-11-15
# 78160       MHL        Oceania                  Marshall Islands  2020-11-15
# 82322       MNG           Asia                          Mongolia  2020-11-15
# 102956      KNA  North America             Saint Kitts and Nevis  2020-11-15
# 104208      VCT  North America  Saint Vincent and the Grenadines  2020-11-15
# 108375      SYC         Africa                        Seychelles  2020-11-15
# 111583      SLB        Oceania                   Solomon Islands  2020-11-15
# 122527      TLS           Asia                             Timor  2020-11-15
# 131643      VUT        Oceania                           Vanuatu  2020-11-15
# 132277      VAT         Europe                           Vatican  2020-11-15
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 67314          24.0        0.0               0.000           NaN         NaN
# 78160           1.0        0.0               0.000           NaN         NaN
# 82322         431.0        3.0               9.857           NaN         NaN
# 102956         19.0        0.0               0.000           NaN         NaN
# 104208         78.0        0.0               0.286           NaN         NaN
# 108375        158.0        0.0               0.571           NaN         NaN
# 111583         16.0        0.0               0.429           NaN         NaN
# 122527         30.0        0.0               0.000           NaN         NaN
# 131643          1.0        0.0               0.143           NaN         NaN
# 132277         27.0        0.0               0.000           NaN         NaN
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 67314                   0.0  ...             7.3          51.2
# 78160                   0.0  ...             NaN           NaN
# 82322                   0.0  ...             5.5          46.5
# 102956                  0.0  ...             NaN           NaN
# 104208                  0.0  ...             NaN           NaN
# 108375                  0.0  ...             7.1          35.7
# 111583                  0.0  ...             NaN           NaN
# 122527                  0.0  ...             6.3          78.1
# 131643                  0.0  ...             2.8          34.5
# 132277                  0.0  ...             NaN           NaN
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 67314                   49.839                         1.5            67.92
# 78160                   82.502                         2.7            73.70
# 82322                   71.180                         7.0            69.87
# 102956                     NaN                         2.3            76.23
# 104208                     NaN                         2.6            72.53
# 108375                     NaN                         3.6            73.40
# 111583                  35.890                         1.4            73.00
# 122527                  28.178                         5.9            69.50
# 131643                  25.209                         NaN            70.47
# 132277                     NaN                         NaN            75.12
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 67314                     0.613                                   NaN
# 78160                     0.704                                   NaN
# 82322                     0.737                                   NaN
# 102956                    0.779                                   NaN
# 104208                    0.738                                   NaN
# 108375                    0.796                                   NaN
# 111583                    0.567                                   NaN
# 122527                    0.606                                   NaN
# 131643                    0.609                                   NaN
# 132277                      NaN                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 67314                           NaN               NaN
# 78160                           NaN               NaN
# 82322                           NaN               NaN
# 102956                          NaN               NaN
# 104208                          NaN               NaN
# 108375                          NaN               NaN
# 111583                          NaN               NaN
# 122527                          NaN               NaN
# 131643                          NaN               NaN
# 132277                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 67314                                       NaN
# 78160                                       NaN
# 82322                                       NaN
# 102956                                      NaN
# 104208                                      NaN
# 108375                                      NaN
# 111583                                      NaN
# 122527                                      NaN
# 131643                                      NaN
# 132277                                      NaN
#
# [10 rows x 67 columns]

# %%
asia_data=df_a[df_a["continent"]=="Asia"]
asia_data=asia_data[~asia_data.isin(["World","International"])]
print(asia_data.head())
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 265        AFG      Asia  Afghanistan  2020-11-15      43035.0       66.0
# 5731       ARM      Asia      Armenia  2020-11-15     117337.0     1482.0
# 8612       AZE      Asia   Azerbaijan  2020-11-15      75688.0     2259.0
# 9881       BHR      Asia      Bahrain  2020-11-15      84703.0      180.0
# 10518      BGD      Asia   Bangladesh  2020-11-15     432333.0     1837.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 265               143.143        1605.0        10.0                7.000  ...
# 5731             1559.000        1763.0        25.0               29.143  ...
# 8612             1468.143         967.0        21.0               18.143  ...
# 9881              178.143         334.0         1.0                0.714  ...
# 10518            1727.857        6194.0        21.0               18.143  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 265               NaN           NaN                  37.746
# 5731              1.5          52.1                  94.043
# 8612              0.3          42.5                  83.241
# 9881              5.8          37.6                     NaN
# 10518             1.0          44.7                  34.808
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 265                           0.5            64.83                    0.511
# 5731                          4.2            75.09                    0.776
# 8612                          4.7            73.00                    0.756
# 9881                          2.0            77.29                    0.852
# 10518                         0.8            72.59                    0.632
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 265                                     NaN                          NaN
# 5731                                    NaN                          NaN
# 8612                                    NaN                          NaN
# 9881                                    NaN                          NaN
# 10518                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 265                 NaN                                      NaN
# 5731                NaN                                      NaN
# 8612                NaN                                      NaN
# 9881                NaN                                      NaN
# 10518               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
asia_max_cases=asia_data.sort_values("total_cases",ascending=False)
fig=plt.figure(figsize=(20,7))
plt.bar(asia_max_cases["location"][:10],asia_max_cases["total_cases"][:10],color=["#e74c3c","#196f3d","#0099ff","#34495e","#99ff33","#9900ff","#ff3399","#cc99ff","#ff9933","#669999"])
plt.xlabel("Countries")
plt.ylabel("Total Covid19 Cases")
plt.title("Asian Countries with Maximum Covid19 Cases",fontsize=20)
plt.show()

# %%
asia_least_cases=asia_data.sort_values("total_cases",ascending=True)
fig=plt.figure(figsize=(20,7))
plt.bar(asia_least_cases["location"][:10],asia_least_cases["total_cases"][:10],color=["#ff9900","#ffff00","#0099ff","#ff0000","#99ff33","#9900ff","#ff3399","#cc99ff","#ff9933","#669999"])
plt.xlabel("Countries")
plt.ylabel("Total Covid19 Cases")
plt.title("Asian Countries with Least Covid19 Cases",fontsize=20)
plt.show()

# %%
#Filtering columns of dataset
df_asia=asia_data[["date","total_cases","new_cases","total_deaths","new_tests","total_tests",
                  "location",'new_deaths_per_million','total_tests_per_thousand','new_tests_per_thousand',
                  'positive_rate','new_deaths']]
df_asia.head()
# Out:
#              date  total_cases  new_cases  total_deaths  new_tests  \
# 265    2020-11-15      43035.0       66.0        1605.0        NaN
# 5731   2020-11-15     117337.0     1482.0        1763.0        NaN
# 8612   2020-11-15      75688.0     2259.0         967.0        NaN
# 9881   2020-11-15      84703.0      180.0         334.0     8805.0
# 10518  2020-11-15     432333.0     1837.0        6194.0    14060.0
#
#        total_tests     location  new_deaths_per_million  \
# 265            NaN  Afghanistan                   0.251
# 5731           NaN      Armenia                   8.423
# 8612           NaN   Azerbaijan                   2.054
# 9881     1894421.0      Bahrain                   0.572
# 10518    2539021.0   Bangladesh                   0.126
#
#        total_tests_per_thousand  new_tests_per_thousand  positive_rate  \
# 265                         NaN                     NaN            NaN
# 5731                        NaN                     NaN          0.428
# 8612                        NaN                     NaN            NaN
# 9881                   1083.582                   5.036          0.018
# 10518                    15.267                   0.085          0.123
#
#        new_deaths
# 265          10.0
# 5731         25.0
# 8612         21.0
# 9881          1.0
# 10518        21.0

# %%
fig=plt.figure(figsize=(15,10))

sns.heatmap(df_asia.corr(),cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %%
#Lineplot of Total Cases vs Total Deaths
plt.figure(figsize=(20,8))
sns.lineplot(x='total_cases',y='total_deaths',data=df_asia,color="#E74C3C")
plt.title("Total Cases vs Total Deaths",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Cases vs Total Deaths')

# %%
#Lineplot of Total number of tests and Positive rate
plt.figure(figsize=(20,8))
sns.lineplot(x='total_tests',y='positive_rate',data=df_asia,color="#009933")
plt.title("Total Tests vs Positive Rate",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Tests vs Positive Rate')

# %%
#Subplot of countries with maximum vaccinated people and least number of vaccinated people
vaccination_data=df[df["date"]=="2021-03-10"]
vaccination_data=vaccination_data[~vaccination_data["location"].isin(["World","International"])]
max_vaccinated=vaccination_data.sort_values("total_vaccinations",ascending= False)
least_vaccinated=vaccination_data.sort_values("total_vaccinations",ascending= True)
fig=plt.figure(figsize=(25,10))
plt.subplot(1,2,1)
plt.barh(max_vaccinated["location"][:10],max_vaccinated["total_vaccinations"][:10],color="#0E6655")
plt.title("Top 10 Countries with Maximum Number of Vaccinated People",fontsize=20)
plt.xlabel("Vaccinations",fontsize=15)
plt.ylabel("Countries",fontsize=15)
plt.subplot(1,2,2)
plt.barh(least_vaccinated["location"][:10],least_vaccinated["total_vaccinations"][:10],color="#2471A3")
plt.title("10 Countries with Least Number of Vaccinated People", fontsize=20)
plt.xlabel("Vaccinations",fontsize=15)
plt.ylabel("Countries",fontsize=15)

plt.show()
